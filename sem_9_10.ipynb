# %% [markdown]
# <a href="https://colab.research.google.com/github/SunshineSen/notSnake/blob/main/sem_9_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head(10)

# %%
df.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16990    -124.22     41.73                28.0       3003.0           699.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16993    -124.23     40.54                52.0       2694.0           453.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16990      1530.0       653.0         1.7038             78300.0
# ...

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 16995      False     False               False        False           False
# 16996      False     False               False        False           False
# 16997      False     False               False        False           False
# 16998      False     False               False        False           False
# 16999      False     False               False        False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
tb = df['total_bedrooms']

# %%
tb.sum()
# Out:
# 9169984.0

# %%
df[['latitude', 'population']]
# Out:
#        latitude  population
# 0         34.19      1015.0
# 1         34.40      1129.0
# 2         33.69       333.0
# 3         33.64       515.0
# 4         33.57       624.0
# ...         ...         ...
# 16995     40.58       907.0
# 16996     40.69      1194.0
# 16997     41.84      1244.0
# 16998     41.80      1298.0
# 16999     40.54       806.0
#
# [17000 rows x 2 columns]

# %%
df[df['housing_median_age'] < 20]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# ...          ...       ...                 ...          ...             ...
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %%
new = df[(df['housing_median_age'] < 20) & (df['total_rooms'] < 30)]

# %%
new
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2907    -117.76     35.22                 4.0         18.0             3.0
# 2990    -117.79     35.21                 4.0          2.0             2.0
# 3275    -117.86     33.67                16.0         20.0             5.0
# 8232    -118.44     34.04                16.0         18.0             6.0
#
#       population  households  median_income  median_house_value
# 2907         8.0         6.0          1.625            275000.0
# 2990         6.0         2.0          2.375            137500.0
# 3275        15.0         5.0          3.875            450000.0
# 8232         3.0         4.0          0.536            350000.0

# %%
new.shape
# Out:
# (4, 9)

# %%
new['population'].min()
# Out:
# 3.0

# %%
new['population'].mean() #среднее значение
# Out:
# 8.0

# %%
df[(df['median_income'] < 2)][['median_house_value', 'total_rooms']]
# Out:
#        median_house_value  total_rooms
# 0                 66900.0       5612.0
# 1                 80100.0       7650.0
# 2                 85700.0        720.0
# 4                 65500.0       1454.0
# 7                 48500.0        812.0
# ...                   ...          ...
# 16984             70000.0       1371.0
# 16989             58100.0       1218.0
# 16990             78300.0       3003.0
# 16994             76100.0       1430.0
# 16998             85800.0       2672.0
#
# [2005 rows x 2 columns]

# %%
df[(df['median_income'] < 2)]['median_house_value'].max()
# Out:
# 500001.0

# %%
df[(df['median_income'] == 3.1250)]['median_house_value'].max()
# Out:
# 380400.0

# %%
df[(df['median_income'] == 3.1250)]['median_house_value'].min()
# Out:
# 37500.0

# %%
ne3 = df['median_house_value'].min()

# %%
df[(df['median_house_value'] == ne3)]['population'].max()
# Out:
# 628.0

# %%
df[(df['median_house_value'] == df['median_house_value'].min())]['population'].max() #в одну строку
# Out:
# 628.0

# %%
import seaborn as sns

# %%
sns.scatterplot(data = df, x = 'longitude', y ='latitude')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data = df, x = 'households', y ='population', hue = 'total_rooms')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
cols = ['population', 'median_income', 'housing_median_age', 'median_house_value']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %%
sns.relplot(x ='latitude', y ='median_house_value', kind ='line', data=df)

# %%
sns.histplot(data=df, x='population')
# Out:
# <Axes: xlabel='population', ylabel='Count'>

# %%
new  = df[df['population'] < 6000]
sns.histplot(data=new, x='population')
# Out:
# <Axes: xlabel='population', ylabel='Count'>

# %%
df.loc[df['housing_median_age'] <=20, 'age_group'] = 'Молодые'
df.loc[(df['housing_median_age'] > 20) & (df['housing_median_age'] <=50), 'age_group'] = 'Ср.возраст'
df.loc[df['housing_median_age'] > 50, 'age_group'] = 'Пожилые'

df.groupby('age_group')['median_income'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='age_group'>
